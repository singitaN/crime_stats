# %% [markdown]
# # Singita Ngobeni on crime Stats

# %%
# lets importb 
import pandas as pd
import matplotlib.pyplot as plt

# %%
crime = pd.read_csv('VOCS2016-2017-HOUSEHOLD_F1.csv')

crime
# Out:
#                      uqno  prov  Q21topiccrime  Q21bHowLong  Q2211Murder  \
# 0      160100720000002601     1              2            3            2
# 1      160100720000006301     1              2            2            2
# 2      160100720000010001     1              2            1            2
# 3      160101220000003001     1              2            3            2
# 4      160101220000006301     1              2            3            2
# 5      160101220000009601     1              2            3            2
# 6      160101220000016201     1              2            3            2
# 7      160101430000000901     1              2            3            2
# 8      160101430000003201     1              1            3            2
# 9      160101430000005501     1              2            3            2
# 10     160101430000007801     1              2            3            2
# 11     160101430000010101     1              2            3            2
# ...

# %% [markdown]
# # now lets just show the Gauteng stats

# %%
gauteng = crime[crime.prov == 7]
gauteng
# Out:
#                      uqno  prov  Q21topiccrime  Q21bHowLong  Q2211Murder  \
# 11815  760100820000001001     7              1            3            1
# 11816  760100820000004101     7              1            2            2
# 11817  760100820000007201     7              2            3            2
# 11818  760100820000010301     7              1            3            2
# 11819  760100820000013401     7              1            3            2
# 11820  760100820000016501     7              2            3            2
# 11821  760100820000022701     7              1            3            2
# 11822  760100820000025801     7              1            3            2
# 11823  760100830000001301     7              2            3            2
# 11824  760100830000002901     7              2            1            2
# 11825  760100830000004501     7              1            3            2
# 11826  760100830000006101     7              2            1            2
# ...

# %%
# code_12 = crime[crime.metro_code==12]

def ct_metro(mCode):
    return gauteng[gauteng.metro_code==mCode]

ct_metro(10)
# Out:
#                      uqno  prov  Q21topiccrime  Q21bHowLong  Q2211Murder  \
# 9132   599100180000000801     5              2            3            2
# 9133   599100180000003201     5              2            3            2
# 9134   599100180000005601     5              2            3            1
# 9135   599100180000008001     5              2            3            2
# 9136   599100180000010401     5              1            3            2
# 9137   599100180000012801     5              2            3            2
# 9138   599100300000007701     5              1            3            2
# 9139   599100300000013301     5              2            3            2
# 9140   599100300000016101     5              2            3            2
# 9141   599100300000018901     5              2            3            2
# 9142   599100430000000901     5              2            2            2
# 9143   599100430000002901     5              2            2            2
# ...

# %% [markdown]
# # lets create a list from the types of crimes

# %%
# lets create a list off the crime stats table

typ_crime = ['Q2211Murder', 'Q2212StrRob', 'Q2213HomeRob', 'Q2213HomeRob', 'Q2214BussRob',
             'Q2215Hijack', 'Q2216Assault', 'Q2217SexAssult', 'Q2218ChildAbuse','Q2219Political', 'Q22110Vigilante',
             'Q22111BagSnatch','Q22112Bicycle','Q22113Car','Q22114Burglary', 'Q22115Crop','Q22116Livestock',
             'Q22117WhiteColl','Q22118damage','Q22119IDtheft','Q22120HumanTr','Q22122HateCrim','Q22123Other']

# lets align the labels together with the typ_crime

crime_labels = ['Murder','street robberies','Home Robberies','bus robberies','Hijacking','Assault','Sex Assult','Child Abuse','Political','Vigilante',
               'Bagsnatching','Bicycle','Car','Burglary','Crop','Livestock','White Collar Crime','Damage','Theft','Human Trafficking','Hate Crime','Other']
